# %%
from src.FLM_client import Client

meteor = Client()
stack = meteor.execute_TEST()
# Out:
# 2023-05-12 00:40:33,410 DEBUG:	COMLOG_CLIENT:socket_connect()	create socket
# 2023-05-12 00:40:33,412 DEBUG:	COMLOG_CLIENT:socket_connect()	Client connect: 10.37.0.105 , 53215
# 2023-05-12 00:40:33,413 DEBUG:	COMLOG_CLIENT:client_worker()	Client asked for: ACQUIRE_Z
# 2023-05-12 00:40:33,414 DEBUG:	COMLOG_CLIENT:_send_package()	Sent BYTES TO SEND: 195
# 2023-05-12 00:40:33,456 DEBUG:	COMLOG_CLIENT:client_worker()	Connection closed successfully
# 2023-05-12 00:40:33,457 ERROR:	COMLOG_CLIENT:execute_TEST()	This command did not work
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 67, in _send_package
#     answer = unpack(conn.recv(TCP_BUFFER))
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 12, in unpack
#     return pickle.loads(codecs.decode(package, encoding=CODEC)) #protocol is detected automatically
# EOFError: Ran out of input
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 980, in emit
#     msg = self.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 830, in format
#     return fmt.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 567, in format
#     record.message = record.getMessage()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 330, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4be77d553f0b>", line 4, in <module>
#     stack = meteor.execute_TEST()
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 55, in execute_TEST
#     answer = self._execute_command()[-1]
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 92, in _execute_command
#     result = client_worker(self.socket,package)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 17, in client_worker
#     _send_package(conn,pkg,logger=logger_client)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 113, in _send_package
#     logger.error('Exception:', ex, )
# Message: 'Exception:'
# Arguments: (EOFError('Ran out of input',),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 67, in _send_package
#     answer = unpack(conn.recv(TCP_BUFFER))
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 12, in unpack
#     return pickle.loads(codecs.decode(package, encoding=CODEC)) #protocol is detected automatically
# EOFError: Ran out of input
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 980, in emit
#     msg = self.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 830, in format
#     return fmt.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 567, in format
#     record.message = record.getMessage()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 330, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4be77d553f0b>", line 4, in <module>
#     stack = meteor.execute_TEST()
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 55, in execute_TEST
#     answer = self._execute_command()[-1]
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 92, in _execute_command
#     result = client_worker(self.socket,package)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 17, in client_worker
#     _send_package(conn,pkg,logger=logger_client)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 113, in _send_package
#     logger.error('Exception:', ex, )
# Message: 'Exception:'
# Arguments: (EOFError('Ran out of input',),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 123, in _receive_package
#     pkg = unpack(conn.recv(TCP_BUFFER))
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 12, in unpack
#     return pickle.loads(codecs.decode(package, encoding=CODEC)) #protocol is detected automatically
# EOFError: Ran out of input
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 980, in emit
#     msg = self.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 830, in format
#     return fmt.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 567, in format
#     record.message = record.getMessage()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 330, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4be77d553f0b>", line 4, in <module>
#     stack = meteor.execute_TEST()
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 55, in execute_TEST
#     answer = self._execute_command()[-1]
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 92, in _execute_command
#     result = client_worker(self.socket,package)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 18, in client_worker
#     conn, pkg = _receive_package(conn,logger=logger_client)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 173, in _receive_package
#     logger.error('Exception:', ex, )
# Message: 'Exception:'
# Arguments: (EOFError('Ran out of input',),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 123, in _receive_package
#     pkg = unpack(conn.recv(TCP_BUFFER))
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 12, in unpack
#     return pickle.loads(codecs.decode(package, encoding=CODEC)) #protocol is detected automatically
# EOFError: Ran out of input
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 980, in emit
#     msg = self.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 830, in format
#     return fmt.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 567, in format
#     record.message = record.getMessage()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 330, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4be77d553f0b>", line 4, in <module>
#     stack = meteor.execute_TEST()
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 55, in execute_TEST
#     answer = self._execute_command()[-1]
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 92, in _execute_command
#     result = client_worker(self.socket,package)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 18, in client_worker
#     conn, pkg = _receive_package(conn,logger=logger_client)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 173, in _receive_package
#     logger.error('Exception:', ex, )
# Message: 'Exception:'
# Arguments: (EOFError('Ran out of input',),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 18, in client_worker
#     conn, pkg = _receive_package(conn,logger=logger_client)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 177, in _receive_package
#     return conn, package
# UnboundLocalError: local variable 'package' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 980, in emit
#     msg = self.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 830, in format
#     return fmt.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 567, in format
#     record.message = record.getMessage()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 330, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4be77d553f0b>", line 4, in <module>
#     stack = meteor.execute_TEST()
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 55, in execute_TEST
#     answer = self._execute_command()[-1]
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 92, in _execute_command
#     result = client_worker(self.socket,package)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 35, in client_worker
#     logger_client.exception('Exception:', ex, )
# Message: 'Exception:'
# Arguments: (UnboundLocalError("local variable 'package' referenced before assignment",),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 18, in client_worker
#     conn, pkg = _receive_package(conn,logger=logger_client)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\package_exchange.py", line 177, in _receive_package
#     return conn, package
# UnboundLocalError: local variable 'package' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 980, in emit
#     msg = self.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 830, in format
#     return fmt.format(record)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 567, in format
#     record.message = record.getMessage()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\logging\__init__.py", line 330, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Program Files\Python35\envs\AutoScript\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4be77d553f0b>", line 4, in <module>
#     stack = meteor.execute_TEST()
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 55, in execute_TEST
#     answer = self._execute_command()[-1]
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py", line 92, in _execute_command
#     result = client_worker(self.socket,package)
#   File "d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\communication\client_worker.py", line 35, in client_worker
#     logger_client.exception('Exception:', ex, )
# Message: 'Exception:'
# Arguments: (UnboundLocalError("local variable 'package' referenced before assignment",),)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-4be77d553f0b> in <module>()
#       2
#       3 meteor = Client()
# ----> 4 stack = meteor.execute_TEST()
#
# d:\User Data\Johann\SerialFIB-MeteorIntegrationVersion\src\FLM_client.py in execute_TEST(self)
#      57                         self.logger.error('This command did not work')
#      58                 finally:
# ---> 59                         return answer
#      60
#      61
#
# UnboundLocalError: local variable 'answer' referenced before assignment

# %%
stack = stack[0]

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
# %matplotlib notebook

time, num_slices, num_channels, height, width = stack.shape

fig, ax = plt.subplots()
plt.subplots_adjust(bottom=0.15)

# Initialize the slice and channel indices
slice_idx = 0
channel_idx = 0

# Plot the initial slice
img = ax.imshow(stack[0,slice_idx, channel_idx], cmap='gray')

# Create a slider for the slice index
ax_slice = plt.axes([0.15, 0.05, 0.7, 0.03])
slider_slice = Slider(ax_slice, 'Slice', 0, num_slices - 1, valinit=slice_idx)

# Create a slider for the channel index
ax_channel = plt.axes([0.15, 0.1, 0.7, 0.03])
slider_channel = Slider(ax_channel, 'Channel', 0, num_channels - 1, valinit=channel_idx)

def update(val):
    #nonlocal slice_idx, channel_idx, img

    # Get the updated slice and channel indices
    slice_idx = int(slider_slice.val)
    channel_idx = int(slider_channel.val)

    # Update the displayed image
    img.set_data(stack[0, slice_idx, channel_idx])
    fig.canvas.draw()

slider_slice.on_changed(update)
slider_channel.on_changed(update)

plt.show()
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using qt instead.
# c:\Program Files\Python35\envs\AutoScript\lib\site-packages\matplotlib\axes\_base.py:2903: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))
